# %%
# !python translate_model_main.py
# Out:
# /storage/home/hcoda1/1/yyu496/.conda/envs/BrainBrige/lib/python3.9/site-packages/transformers/models/auto/auto_factory.py:471: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /storage/home/hcoda1/1/yyu496/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /storage/home/hcoda1/1/yyu496/nltk_data...
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /storage/home/hcoda1/1/yyu496/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /storage/home/hcoda1/1/yyu496/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /storage/home/hcoda1/1/yyu496/nltk_data...
# ...

# %%
rm -rf /storage/home/yyu496/1/yyu496/nltk_data/tokenizers/punkt_tab

# %%
import shutil

# Define the path to the .cache/huggingface directory
cache_dir = '/storage/coda1/p-fnajafi3/0/yyu496/.cache/huggingface'

# Delete the directory and its contents
try:
    shutil.rmtree(cache_dir)
    print(f"Deleted '{cache_dir}' successfully.")
except FileNotFoundError:
    print(f"The directory '{cache_dir}' does not exist.")
except PermissionError:
    print(f"Permission denied to delete '{cache_dir}'.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# The directory '/storage/coda1/p-fnajafi3/0/yyu496/.cache/huggingface' does not exist.

# %%
import shutil

# Define the path to the .cache/huggingface directory
cache_dir = '/storage/coda1/p-cwiese7/0/yyu496/.cache/huggingface'

# Delete the directory and its contents
try:
    shutil.rmtree(cache_dir)
    print(f"Deleted '{cache_dir}' successfully.")
except FileNotFoundError:
    print(f"The directory '{cache_dir}' does not exist.")
except PermissionError:
    print(f"Permission denied to delete '{cache_dir}'.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Deleted '/storage/coda1/p-cwiese7/0/yyu496/.cache/huggingface' successfully.

# %%
import shutil

# Define the path to the .cache/huggingface directory
cache_dir = '/storage/home/hcoda1/1/yyu496/.cache/huggingface'

# Delete the directory and its contents
try:
    shutil.rmtree(cache_dir)
    print(f"Deleted '{cache_dir}' successfully.")
except FileNotFoundError:
    print(f"The directory '{cache_dir}' does not exist.")
except PermissionError:
    print(f"Permission denied to delete '{cache_dir}'.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# The directory '/storage/home/hcoda1/1/yyu496/.cache/huggingface' does not exist.

# %%
# !nvidia-smi
# Out:
# Sun Mar  9 22:45:52 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 555.42.02              Driver Version: 555.42.02      CUDA Version: 12.5     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA H100 80GB HBM3          On  |   00000000:BE:00.0 Off |                    0 |
# | N/A   33C    P0             71W /  700W |       1MiB /  81559MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("~/p-cwiese7-0/data/cleaned_final_jargon_dataset.csv")

# %%
df
# Out:
#               jargon                                        translation  \
# 0         Cantilever  A long projecting beam or girder fixed at only...
# 1             Facade  The face of a building, especially the princip...
# 2       Fenestration  The design and placement of windows in a build...
# 3           Pediment  The triangular upper part of the front of a bu...
# 4              Quoin  The outside corner of a wall or building, ofte...
# ...              ...                                                ...
# 5279  synergyvantage                                     No translation
# 5280        artistry                                     No translation
# 5281       dominance                                     No translation
# 5282   synchronosity                                     No translation
# 5283  sophistication                                     No translation
#
#          discipline                                           sentence
# ...

# %%
df = df.where(df['translation'] != 'No translation').dropna()

# %%
df['sentence'] = df['sentence'].apply(lambda x: x.strip('""'))

# %%
df.
# Out:
#                       jargon  \
# 0                 Cantilever
# 1                     Facade
# 2               Fenestration
# 3                   Pediment
# 4                      Quoin
# ...                      ...
# 3926         Latent Learning
# 3927        Dopamine Release
# 3928          Arousal Theory
# 3929               Dysthymia
# 3930  Interpersonal Dynamics
#
#                                             translation    discipline  \
# 0     A long projecting beam or girder fixed at only...  Architecture
# 1     The face of a building, especially the princip...  Architecture
# 2     The design and placement of windows in a build...  Architecture
# 3     The triangular upper part of the front of a bu...  Architecture
# 4     The outside corner of a wall or building, ofte...  Architecture
# ...                                                 ...           ...
# 3926  Learning that occurs without any obvious reinf...    Psychology
# ...
